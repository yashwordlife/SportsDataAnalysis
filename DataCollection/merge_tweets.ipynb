# %%
import pandas as pd

# %%
df1 = pd.read_csv("baseball1.csv")
df2 = pd.read_csv("baseball2.csv")
df3 = pd.read_csv("baseball3.csv")
df4 = pd.read_csv("baseball4.csv")
df5 = pd.read_csv("baseball5.csv")
df6 = pd.read_csv("baseball6.csv")
df7 = pd.read_csv("baseball7.csv")
df8 = pd.read_csv("baseball8.csv")
df9 = pd.read_csv("baseball9.csv")
df10 = pd.read_csv("baseball10.csv")

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10]

# %%
result = pd.concat(frames)

# %%
result = result.drop_duplicates()

# %%
result.to_csv('baseball_merge1.csv')

# %%
result
# Out:
#      Unnamed: 0                                              tweet
# 0             0  @lionessmom76 watching little league baseball....
# 1             1  I don’t like Baseball but I like Mike Trout. H...
# 2             2      Palmyra Baseball 2019 https://t.co/KpohTMAkEB
# 3             3               He's a Benjamin Button baseball boy!
# 4             4  Jason Heyward hits his 4th home run, but Yu Da...
# 5             5  @kasekubrick_ They had a record offensive seas...
# 6             6  Picked up a last minute baseball game with @AM...
# 7             7      Baseball is not fair. https://t.co/c1HQig1p5p
# 8             8  @KateUpton @houzz @motivohome Glad u guys are ...
# 9             9  @LlaroldLive @fakemikemulloy So, baseball is j...
# 10           10  Royals', Whit's streaks continue against Marin...
# 11           11  Tunnel Rats should be sent packing along with ...
# 12           12  @SabreMatt @DimFilipovic @dj_mitchell94 Nah, a...
# ...
